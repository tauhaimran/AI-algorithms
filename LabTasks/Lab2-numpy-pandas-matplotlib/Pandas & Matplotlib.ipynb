# %% [markdown]
# # **Pandas**
#
# Pandas is a powerful and easy-to-use Python library for data manipulation and analysis

# %% [markdown]
# - **Series** : Series holds one dimentional data just like on column or a list
# - **DataFrame** : DataFrame hold two dimensional data as data in tablular formate

# %%
# series
import pandas as pd
data=[1,2,3,4,5]
data=pd.Series(data)
print(data)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# Dataframe

data={
    "name":["ali","ahmad"],
    "age":[23,24]
}
data=pd.DataFrame(data)
print(data)
# Out:
#     name  age
# 0    ali   23
# 1  ahmad   24

# %%
# load a dataset
df=pd.read_csv("kc_house_data.csv")
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
# 4      8080     1.0           0     0  ...      8      1680.0              0
#
# ...

# %%
# some basic functions 

df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
# 4      8080     1.0           0     0  ...      8      1680.0              0
#
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608      1530.0              0      2009             0    98103  47.6993
# ...

# %%
print(df.shape)
# Out:
# (21613, 21)

# %%
print(df.columns)
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
# Pandas use the loc attribute to return one or more specified row(s)
df.loc[0:3]
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# ...

# %%
# selecting specified columns
df["date"]
# Out:
# 0        20141013T000000
# 1        20141209T000000
# 2        20150225T000000
# 3        20141209T000000
# 4        20150218T000000
#               ...
# 21608    20140521T000000
# 21609    20150223T000000
# 21610    20140623T000000
# 21611    20150116T000000
# 21612    20141015T000000
# Name: date, Length: 21613, dtype: object

# %%
# selecting multiple columns
df[["date","price"]]
# Out:
#                   date     price
# 0      20141013T000000  221900.0
# 1      20141209T000000  538000.0
# 2      20150225T000000  180000.0
# 3      20141209T000000  604000.0
# 4      20150218T000000  510000.0
# ...                ...       ...
# 21608  20140521T000000  360000.0
# 21609  20150223T000000  400000.0
# 21610  20140623T000000  402101.0
# 21611  20150116T000000  400000.0
# 21612  20141015T000000  325000.0
#
# [21613 rows x 2 columns]

# %%
# filter the data based on come condition
high_price = df[df["price"] > 1000000]
print(high_price.shape)
# Out:
# (1465, 21)

# %%
#sorting the dataframe based on a price in decending order
high_price.sort_values("price",ascending=False)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 7252   6762700020  20141013T000000  7700000.0         6       8.00
# 3914   9808700762  20140611T000000  7062500.0         5       4.50
# 9254   9208900037  20140919T000000  6885000.0         6       7.75
# 4411   2470100110  20140804T000000  5570000.0         5       5.75
# 1448   8907500070  20150413T000000  5350000.0         5       5.00
# ...           ...              ...        ...       ...        ...
# 19194  1337800220  20140908T000000  1003000.0         4       2.50
# 3282   2125059112  20150326T000000  1003000.0         5       2.50
# 8177   1257200115  20140521T000000  1003000.0         4       2.75
# 19024  6815100085  20141224T000000  1001000.0         4       2.00
# 2717   9808590310  20150408T000000  1000750.0         3       2.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 7252         12050     27600     2.5           0     3  ...     13
# ...

# %%
high_price
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 21     2524049179  20140826T000000  2000000.0         3       2.75
# 49      822039084  20150311T000000  1350000.0         3       2.50
# 69     1802000060  20140612T000000  1325000.0         5       2.25
# 70     1525059190  20140912T000000  1040000.0         5       3.25
# ...           ...              ...        ...       ...        ...
# 21590  7430200100  20140514T000000  1222500.0         4       3.50
# 21593  8672200110  20150317T000000  1088000.0         5       3.75
# 21597   191100405  20150421T000000  1575000.0         4       3.25
# 21600   249000205  20141015T000000  1537000.0         5       3.75
# 21606  7936000429  20150326T000000  1007500.0         4       3.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 5             5420    101930     1.0           0     0  ...     11
# ...

# %%
# selecting row based on the index 
high_price.loc[21]
# Out:
# id                    2524049179
# date             20140826T000000
# price                  2000000.0
# bedrooms                       3
# bathrooms                   2.75
# sqft_living                 3050
# sqft_lot                   44867
# floors                       1.0
# waterfront                     0
# view                           4
# condition                      3
# grade                          9
# sqft_above                2330.0
# sqft_basement                720
# yr_built                    1968
# yr_renovated                   0
# zipcode                    98040
# lat                      47.5316
# long                    -122.233
# sqft_living15               4110
# sqft_lot15                 20336
# Name: 21, dtype: object

# %%
# selecting the row based on the actual position
high_price.iloc[1]
# Out:
# id                    2524049179
# date             20140826T000000
# price                  2000000.0
# bedrooms                       3
# bathrooms                   2.75
# sqft_living                 3050
# sqft_lot                   44867
# floors                       1.0
# waterfront                     0
# view                           4
# condition                      3
# grade                          9
# sqft_above                2330.0
# sqft_basement                720
# yr_built                    1968
# yr_renovated                   0
# zipcode                    98040
# lat                      47.5316
# long                    -122.233
# sqft_living15               4110
# sqft_lot15                 20336
# Name: 21, dtype: object

# %%
# making new features and adding a column 
df["tax"]=df["price"]*0.10
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      1180.0              0
# 1      7242     2.0           0     0  ...      2170.0            400
# 2     10000     1.0           0     0  ...       770.0              0
# 3      5000     1.0           0     0  ...      1050.0            910
# 4      8080     1.0           0     0  ...      1680.0              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
# drop a column 
df.drop("taxed_price",axis=1,inplace=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 2
#       1 # drop a column
# ----> 2 df.drop("taxed_price",axis=1,inplace=True)
#       3 df.head()
#
# File c:\Users\misma\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
# ...

# %%
# droping rows where there is null values
df.dropna(inplace=True)

# replace null values with other value
df.fillna(1,inplace=True)

# droping row based on the null value in a specified column
df.dropna(subset=['Date'], inplace = True)

# %%
# make average of column in a dataframe
df.groupby('floors').mean(numeric_only=True)
# Out:
#                   id         price  bedrooms  bathrooms  sqft_living  \
# floors
# 1.0     4.517702e+09  4.421600e+05  3.160689   1.751451  1731.674970
# 1.5     4.548548e+09  5.590194e+05  3.506024   1.772132  1908.041907
# 2.0     4.677829e+09  6.488912e+05  3.631234   2.622619  2571.279092
# 2.5     4.578060e+09  1.060346e+06  3.987578   2.835404  3145.428571
# 3.0     4.475630e+09  5.825260e+05  2.952692   2.489804  1788.311582
# 3.5     3.390713e+09  9.333125e+05  3.000000   2.531250  2518.000000
#
#             sqft_lot  waterfront      view  condition     grade  ...  \
# floors                                                           ...
# 1.0     14568.852327    0.005338  0.213597   3.550894  7.148890  ...
# 1.5     16973.111577    0.011001  0.249869   3.689366  7.192771  ...
# 2.0     16133.744448    0.009101  0.248149   3.187841  8.360272  ...
# 2.5     17347.291925    0.012422  0.509317   3.478261  8.894410  ...
# ...

# %%
# reset the index drop false remove the old indexes without keeping them 
df.reset_index(drop=False, inplace=False)
# Out:
#        index          id             date     price  bedrooms  bathrooms  \
# 0          0  7129300520  20141013T000000  221900.0         3       1.00
# 1          1  6414100192  20141209T000000  538000.0         3       2.25
# 2          2  5631500400  20150225T000000  180000.0         2       1.00
# 3          3  2487200875  20141209T000000  604000.0         4       3.00
# 4          4  1954400510  20150218T000000  510000.0         3       2.00
# ...      ...         ...              ...       ...       ...        ...
# 21608  21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611  21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  ...  sqft_above  \
# ...

# %%
# detecting the duplicates
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21608    False
# 21609    False
# 21610    False
# 21611    False
# 21612    False
# Length: 21613, dtype: bool

# %%
#remove the duplicates 
df.drop_duplicates()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_above  \
# 0             1180      5650     1.0           0     0  ...      1180.0
# ...

# %%
# print the rows which are duplicated 
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15, tax]
# Index: []
#
# [0 rows x 22 columns]

# %%
# keep the last row of the duplicates
df = df.drop_duplicates(keep='last')

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above       float64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# tax              float64
# dtype: object

# %%
# correlation in columns
columns_for_corr=[]
for column in df.columns:
    if column != "date":
        columns_for_corr.append(column)
print(columns_for_corr)


df[columns_for_corr].corr()
# Out:
# ['id', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15', 'tax']
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# ...

# %%
# finding the correlation of columns with the target variable
df.drop("date",axis=1).corr()['price']
# Out:
# id              -0.016762
# price            1.000000
# bedrooms         0.308350
# bathrooms        0.525138
# sqft_living      0.702035
# sqft_lot         0.089661
# floors           0.256794
# waterfront       0.266369
# view             0.397293
# condition        0.036362
# grade            0.667434
# sqft_above       0.605567
# sqft_basement    0.323816
# yr_built         0.054012
# yr_renovated     0.126434
# zipcode         -0.053203
# lat              0.307003
# long             0.021626
# sqft_living15    0.585379
# sqft_lot15       0.082447
# tax              1.000000
# Name: price, dtype: float64

# %% [markdown]
# # Matplotlib
#
# Python libray for plotting data and making different charts and graphs

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      1180.0              0
# 1      7242     2.0           0     0  ...      2170.0            400
# 2     10000     1.0           0     0  ...       770.0              0
# 3      5000     1.0           0     0  ...      1050.0            910
# 4      8080     1.0           0     0  ...      1680.0              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.drop("date",axis=1).corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
columns=df.columns
corr=df[columns[4:7]].corr()
plt.figure(figsize=(12, 8))
sns.heatmap(corr, annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %%
df[columns[4:7]].corr()
# Out:
#              bathrooms  sqft_living  sqft_lot
# bathrooms     1.000000     0.754665  0.087740
# sqft_living   0.754665     1.000000  0.172826
# sqft_lot      0.087740     0.172826  1.000000

# %%
# scatter plot in matplotliab
plt.figure(figsize=(10,5))
plt.scatter(x=df["bedrooms"],y=df["bathrooms"],color="red",marker="o",s=50,alpha=0.7,edgecolors="black")
plt.xlabel("bedrooms")
plt.ylabel("bathrooms")
plt.title("Bedrooms Vs Bathrooms Comparision")
plt.show()

# %%
# line plot in matplotliab

plt.figure(figsize=(10,5))
plt.plot(df["bedrooms"],df["bathrooms"],color="red",marker="o",alpha=0.7)
plt.xlabel("bedrooms")
plt.ylabel("bathrooms")
plt.title("Bedrooms Vs Bathrooms Comparision")
plt.show()
